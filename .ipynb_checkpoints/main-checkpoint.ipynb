# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('Dataset/secondary_data.csv', sep=";")

# Distribution of the class variable ( edible or poisonous ) using seaborn
sns.countplot(x='class', data=df)
plt.title('Edible vs Poisonous')
plt.show()

# %%
df.head()
# Out:
#   class  cap-diameter cap-shape cap-surface cap-color does-bruise-or-bleed  \
# 0     p         15.26         x           g         o                    f
# 1     p         16.60         x           g         o                    f
# 2     p         14.07         x           g         o                    f
# 3     p         14.17         f           h         e                    f
# 4     p         14.64         x           h         o                    f
#
#   gill-attachment gill-spacing gill-color  stem-height  ...  stem-root  \
# 0               e          NaN          w        16.95  ...          s
# 1               e          NaN          w        17.99  ...          s
# 2               e          NaN          w        17.80  ...          s
# 3               e          NaN          w        15.77  ...          s
# 4               e          NaN          w        16.53  ...          s
#
#   stem-surface stem-color veil-type veil-color has-ring ring-type  \
# 0            y          w         u          w        t         g
# 1            y          w         u          w        t         g
# 2            y          w         u          w        t         g
# 3            y          w         u          w        t         p
# 4            y          w         u          w        t         p
#
#   spore-print-color habitat season
# 0               NaN       d      w
# 1               NaN       d      u
# 2               NaN       d      w
# 3               NaN       d      w
# 4               NaN       d      w
#
# [5 rows x 21 columns]

# %%
df.tail()
# Out:
#       class  cap-diameter cap-shape cap-surface cap-color  \
# 61064     p          1.18         s           s         y
# 61065     p          1.27         f           s         y
# 61066     p          1.27         s           s         y
# 61067     p          1.24         f           s         y
# 61068     p          1.17         s           s         y
#
#       does-bruise-or-bleed gill-attachment gill-spacing gill-color  \
# 61064                    f               f            f          f
# 61065                    f               f            f          f
# 61066                    f               f            f          f
# 61067                    f               f            f          f
# 61068                    f               f            f          f
#
#        stem-height  ...  stem-root stem-surface stem-color veil-type  \
# 61064         3.93  ...        NaN          NaN          y       NaN
# 61065         3.18  ...        NaN          NaN          y       NaN
# 61066         3.86  ...        NaN          NaN          y       NaN
# 61067         3.56  ...        NaN          NaN          y       NaN
# 61068         3.25  ...        NaN          NaN          y       NaN
#
#       veil-color has-ring ring-type spore-print-color habitat season
# 61064        NaN        f         f               NaN       d      a
# 61065        NaN        f         f               NaN       d      a
# 61066        NaN        f         f               NaN       d      u
# 61067        NaN        f         f               NaN       d      u
# 61068        NaN        f         f               NaN       d      u
#
# [5 rows x 21 columns]

# %%
df.describe()
# Out:
#        cap-diameter   stem-height    stem-width
# count  61069.000000  61069.000000  61069.000000
# mean       6.733854      6.581538     12.149410
# std        5.264845      3.370017     10.035955
# min        0.380000      0.000000      0.000000
# 25%        3.480000      4.640000      5.210000
# 50%        5.860000      5.950000     10.190000
# 75%        8.540000      7.740000     16.570000
# max       62.340000     33.920000    103.910000

# %% [markdown]
# # 1. Data Cleaning

# %% [markdown]
# ## 1.1. Missing Values

# %%
# Checking for null values
df.isnull().sum()
# Out:
# class                       0
# cap-diameter                0
# cap-shape                   0
# cap-surface             14120
# cap-color                   0
# does-bruise-or-bleed        0
# gill-attachment          9884
# gill-spacing            25063
# gill-color                  0
# stem-height                 0
# stem-width                  0
# stem-root               51538
# stem-surface            38124
# stem-color                  0
# veil-type               57892
# veil-color              53656
# has-ring                    0
# ring-type                2471
# spore-print-color       54715
# habitat                     0
# season                      0
# dtype: int64

# %%
# Percentage of null values
df.isnull().sum()/len(df)*100
# Out:
# class                    0.000000
# cap-diameter             0.000000
# cap-shape                0.000000
# cap-surface             23.121387
# cap-color                0.000000
# does-bruise-or-bleed     0.000000
# gill-attachment         16.184971
# gill-spacing            41.040462
# gill-color               0.000000
# stem-height              0.000000
# stem-width               0.000000
# stem-root               84.393064
# stem-surface            62.427746
# stem-color               0.000000
# veil-type               94.797688
# veil-color              87.861272
# has-ring                 0.000000
# ring-type                4.046243
# spore-print-color       89.595376
# habitat                  0.000000
# season                   0.000000
# dtype: float64

# %% [markdown]
# ### 1.1.1 Drop columns

# %%
# Dropping columns with more than 20% null values
df.drop(['cap-surface', 'gill-spacing','stem-root', 'stem-surface', 'veil-type', 'veil-color', 'spore-print-color'], axis=1, inplace=True)

# %%
# Percentage of null values
df.isnull().sum()/len(df)*100
# Out:
# class                    0.000000
# cap-diameter             0.000000
# cap-shape                0.000000
# cap-color                0.000000
# does-bruise-or-bleed     0.000000
# gill-attachment         16.184971
# gill-color               0.000000
# stem-height              0.000000
# stem-width               0.000000
# stem-color               0.000000
# has-ring                 0.000000
# ring-type                4.046243
# habitat                  0.000000
# season                   0.000000
# dtype: float64

# %% [markdown]
# ### 1.1.2 Checking Gill Attachment

# %%
# unique values in gill attachment
df['gill-attachment'].unique()
# Out:
# array(['e', nan, 'a', 'd', 's', 'x', 'p', 'f'], dtype=object)

# %%
# mode of gill-attachment
df['gill-attachment'].mode()
# Out:
# 0    a
# Name: gill-attachment, dtype: object

# %%
# remove null rows from gill-attachment
df = df.dropna(subset=['gill-attachment'])

# %%
# Percentage of null values
df.isnull().sum()/len(df)*100
# Out:
# class                   0.000000
# cap-diameter            0.000000
# cap-shape               0.000000
# cap-color               0.000000
# does-bruise-or-bleed    0.000000
# gill-attachment         0.000000
# gill-color              0.000000
# stem-height             0.000000
# stem-width              0.000000
# stem-color              0.000000
# has-ring                0.000000
# ring-type               4.137931
# habitat                 0.000000
# season                  0.000000
# dtype: float64

# %% [markdown]
# ### 1.1.3 Checking ring-type

# %%
# unique values in ring-type
df['ring-type'].unique()
# Out:
# array(['g', 'p', 'e', 'l', 'f', nan, 'r', 'z'], dtype=object)

# %%
# mode of ring-type
df['ring-type'].mode()
# Out:
# 0    f
# Name: ring-type, dtype: object

# %%
# remove null rows from ring-type
df = df.dropna(subset=['ring-type'])

# %%
# Percentage of null values
df.isnull().sum()/len(df)*100
# Out:
# class                   0.0
# cap-diameter            0.0
# cap-shape               0.0
# cap-color               0.0
# does-bruise-or-bleed    0.0
# gill-attachment         0.0
# gill-color              0.0
# stem-height             0.0
# stem-width              0.0
# stem-color              0.0
# has-ring                0.0
# ring-type               0.0
# habitat                 0.0
# season                  0.0
# dtype: float64

# %%
# has-ring has (t and f) convert them to True and False
df['has-ring'] = df['has-ring'].map({'t': True, 'f': False})

# %% [markdown]
# ## 1.2 Duplicates

# %%
# sum of duplicates variables
df.duplicated().sum()
# Out:
# 117

# %%
# Dropping duplicate rows
df.drop_duplicates(inplace=True)

df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# ## 1.3 Outliers

# %%
# Function to get Outliers
def get_outliers(df, column):
    q1 = df[column].quantile(0.25)
    q3 = df[column].quantile(0.75)
    iqr = q3 - q1
    lower_bound = q1 - 1.5 * iqr
    upper_bound = q3 + 1.5 * iqr
    return df[(df[column] < lower_bound) | (df[column] > upper_bound)]

def get_outlier_count(df, columns):
    result = []
    for column in columns:
        q1 = df[column].quantile(0.25)
        q3 = df[column].quantile(0.75)
        iqr = q3 - q1
        lower_bound = q1 - 1.5 * iqr
        upper_bound = q3 + 1.5 * iqr
        result.append(len(df[(df[column] < lower_bound) | (df[column] > upper_bound)]))
    return result

# Outliers in cap-diameter
cap_diameter_outliers = get_outliers(df, 'cap-diameter')

# Outliers in stem-height
stem_height_outliers = get_outliers(df, 'stem-height')

# Outliers in stem-width
stem_width_outliers = get_outliers(df, 'stem-width')

print(f"Cap Diameter Outliers: {len(cap_diameter_outliers)}\nStem Height Outliers: {len(stem_height_outliers)}\nStem Width Outliers: {len(stem_width_outliers)}")
# Out:
# Cap Diameter Outliers: 2120
# Stem Height Outliers: 3383
# Stem Width Outliers: 1946

# %%
# Dropping outliers
df = df[~df['cap-diameter'].isin(cap_diameter_outliers['cap-diameter'])]
df = df[~df['stem-height'].isin(stem_height_outliers['stem-height'])]
df = df[~df['stem-width'].isin(stem_width_outliers['stem-width'])]

# %% [markdown]
# # 2. Data Pre-Processing
# ## 2.1 Feature Engineering
# ### 2.1.1 Creating New Features

# %%
# Using '+' operator to concatenate columns
df['habitatXseason'] = df['habitat'] + df['season']
df['habitatXseason'].unique()
# Out:
# array(['da', 'du', 'ma', 'mu', 'gu', 'ha', 'ga', 'hu', 'lu', 'la', 'lw',
#        'dw', 'gw', 'ds', 'ms', 'mw', 'gs', 'pu', 'pa', 'hs', 'wu', 'wa',
#        'us', 'ua', 'uu', 'ls'], dtype=object)

# %%
# Count of unique values in habitatXseason count and count as a percentage
habitatXseason_count = df['habitatXseason'].value_counts()
habitatXseason_percentage = df['habitatXseason'].value_counts(normalize=True) * 100

# Custom dataframe for habitatXseason
habitatXseason = pd.DataFrame({'count': habitatXseason_count, 'percentage': habitatXseason_percentage})
habitatXseason

# remove habitat and season columns
df.drop(['habitat', 'season'], axis=1, inplace=True)

# %% [markdown]
# ### 2.1.2 Feature Encoding

# %%
# Create dummy variables using one-hot encoding 
dummy_habitatXseason = pd.get_dummies(df['habitatXseason'])
dummy_class = pd.get_dummies(df['class'])

# Concatenate the dummy variables with the original DataFrame
df = pd.concat([df, dummy_habitatXseason, dummy_class], axis=1)

# Drop the original categorical columns
df.drop(['habitatXseason', 'class'], axis=1, inplace=True)

df
# Out:
#        cap-diameter cap-shape cap-color does-bruise-or-bleed gill-attachment  \
# 353            6.87         x         n                    f               e
# 354            8.59         p         n                    f               e
# 355            5.95         p         n                    f               e
# 356            6.51         x         n                    f               e
# 357            7.66         x         n                    f               e
# ...             ...       ...       ...                  ...             ...
# 61064          1.18         s         y                    f               f
# 61065          1.27         f         y                    f               f
# 61066          1.27         s         y                    f               f
# 61067          1.24         f         y                    f               f
# 61068          1.17         s         y                    f               f
#
#       gill-color  stem-height  stem-width stem-color  has-ring  ...     mw  \
# 353            w         6.88       13.64          w      True  ...  False
# 354            w         9.15       17.34          w      True  ...  False
# 355            w         7.54       12.73          w      True  ...  False
# 356            w         6.80       12.92          w      True  ...  False
# 357            w         8.55       14.98          w      True  ...  False
# ...          ...          ...         ...        ...       ...  ...    ...
# 61064          f         3.93        6.22          y     False  ...  False
# 61065          f         3.18        5.43          y     False  ...  False
# 61066          f         3.86        6.37          y     False  ...  False
# 61067          f         3.56        5.44          y     False  ...  False
# 61068          f         3.25        5.45          y     False  ...  False
#
#           pa     pu     ua     us     uu     wa     wu      e     p
# 353    False  False  False  False  False  False  False  False  True
# 354    False  False  False  False  False  False  False  False  True
# 355    False  False  False  False  False  False  False  False  True
# 356    False  False  False  False  False  False  False  False  True
# 357    False  False  False  False  False  False  False  False  True
# ...      ...    ...    ...    ...    ...    ...    ...    ...   ...
# 61064  False  False  False  False  False  False  False  False  True
# 61065  False  False  False  False  False  False  False  False  True
# 61066  False  False  False  False  False  False  False  False  True
# 61067  False  False  False  False  False  False  False  False  True
# 61068  False  False  False  False  False  False  False  False  True
#
# [43478 rows x 39 columns]

# %%
# describe dataset
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 43478 entries, 353 to 61068
# Data columns (total 39 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   cap-diameter          43478 non-null  float64
#  1   cap-shape             43478 non-null  object
#  2   cap-color             43478 non-null  object
#  3   does-bruise-or-bleed  43478 non-null  object
#  4   gill-attachment       43478 non-null  object
#  5   gill-color            43478 non-null  object
#  6   stem-height           43478 non-null  float64
#  7   stem-width            43478 non-null  float64
#  8   stem-color            43478 non-null  object
#  9   has-ring              43478 non-null  bool
#  10  ring-type             43478 non-null  object
#  11  da                    43478 non-null  bool
#  12  ds                    43478 non-null  bool
#  13  du                    43478 non-null  bool
#  14  dw                    43478 non-null  bool
#  15  ga                    43478 non-null  bool
#  16  gs                    43478 non-null  bool
#  17  gu                    43478 non-null  bool
#  18  gw                    43478 non-null  bool
#  19  ha                    43478 non-null  bool
#  20  hs                    43478 non-null  bool
#  21  hu                    43478 non-null  bool
#  22  la                    43478 non-null  bool
#  23  ls                    43478 non-null  bool
#  24  lu                    43478 non-null  bool
#  25  lw                    43478 non-null  bool
#  26  ma                    43478 non-null  bool
#  27  ms                    43478 non-null  bool
#  28  mu                    43478 non-null  bool
#  29  mw                    43478 non-null  bool
#  30  pa                    43478 non-null  bool
#  31  pu                    43478 non-null  bool
#  32  ua                    43478 non-null  bool
#  33  us                    43478 non-null  bool
#  34  uu                    43478 non-null  bool
#  35  wa                    43478 non-null  bool
#  36  wu                    43478 non-null  bool
#  37  e                     43478 non-null  bool
#  38  p                     43478 non-null  bool
# dtypes: bool(29), float64(3), object(7)
# memory usage: 4.9+ MB

# %%
# Encode Variables
dummy_cap_shape = pd.get_dummies(df['cap-shape'], prefix='cap_shape')
dummy_cap_color = pd.get_dummies(df['cap-color'], prefix='cap_color')
dummy_does_bruise_or_bleed = pd.get_dummies(df['does-bruise-or-bleed'], prefix='bruise_or_bleed')
dummy_gill_attachment = pd.get_dummies(df['gill-attachment'], prefix='gill_attachment')
dummy_gill_color = pd.get_dummies(df['gill-color'], prefix='gill_color')
dummy_stem_color = pd.get_dummies(df['stem-color'], prefix='stem_color')
dummy_ring_type = pd.get_dummies(df['ring-type'], prefix='ring_type')

# Remove original variables
df.drop(['cap-shape', 'cap-color', 'does-bruise-or-bleed', 'gill-attachment', 'gill-color', 'stem-color', 'ring-type'], axis=1, inplace=True)

# Concatenate the dummy variables with the original DataFrame
df = pd.concat([df, dummy_cap_shape, dummy_cap_color, dummy_does_bruise_or_bleed, dummy_gill_attachment, dummy_gill_color, dummy_stem_color, dummy_ring_type], axis=1)

df
# Out:
#        cap-diameter  stem-height  stem-width  has-ring     da     ds     du  \
# 353            6.87         6.88       13.64      True   True  False  False
# 354            8.59         9.15       17.34      True   True  False  False
# 355            5.95         7.54       12.73      True  False  False   True
# 356            6.51         6.80       12.92      True   True  False  False
# 357            7.66         8.55       14.98      True   True  False  False
# ...             ...          ...         ...       ...    ...    ...    ...
# 61064          1.18         3.93        6.22     False   True  False  False
# 61065          1.27         3.18        5.43     False   True  False  False
# 61066          1.27         3.86        6.37     False  False  False   True
# 61067          1.24         3.56        5.44     False  False  False   True
# 61068          1.17         3.25        5.45     False  False  False   True
#
#           dw     ga     gs  ...  stem_color_u  stem_color_w  stem_color_y  \
# 353    False  False  False  ...         False          True         False
# 354    False  False  False  ...         False          True         False
# 355    False  False  False  ...         False          True         False
# 356    False  False  False  ...         False          True         False
# 357    False  False  False  ...         False          True         False
# ...      ...    ...    ...  ...           ...           ...           ...
# 61064  False  False  False  ...         False         False          True
# 61065  False  False  False  ...         False         False          True
# 61066  False  False  False  ...         False         False          True
# 61067  False  False  False  ...         False         False          True
# 61068  False  False  False  ...         False         False          True
#
#        ring_type_e  ring_type_f  ring_type_g  ring_type_l  ring_type_p  \
# 353          False        False        False        False         True
# 354          False        False        False        False         True
# 355          False        False        False        False         True
# 356          False        False        False        False         True
# 357          False        False        False        False         True
# ...            ...          ...          ...          ...          ...
# 61064        False         True        False        False        False
# 61065        False         True        False        False        False
# 61066        False         True        False        False        False
# 61067        False         True        False        False        False
# 61068        False         True        False        False        False
#
#        ring_type_r  ring_type_z
# 353          False        False
# 354          False        False
# 355          False        False
# 356          False        False
# 357          False        False
# ...            ...          ...
# 61064        False        False
# 61065        False        False
# 61066        False        False
# 61067        False        False
# 61068        False        False
#
# [43478 rows x 91 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 43478 entries, 353 to 61068
# Data columns (total 91 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   cap-diameter       43478 non-null  float64
#  1   stem-height        43478 non-null  float64
#  2   stem-width         43478 non-null  float64
#  3   has-ring           43478 non-null  bool
#  4   da                 43478 non-null  bool
#  5   ds                 43478 non-null  bool
#  6   du                 43478 non-null  bool
#  7   dw                 43478 non-null  bool
#  8   ga                 43478 non-null  bool
#  9   gs                 43478 non-null  bool
#  10  gu                 43478 non-null  bool
#  11  gw                 43478 non-null  bool
#  12  ha                 43478 non-null  bool
#  13  hs                 43478 non-null  bool
#  14  hu                 43478 non-null  bool
#  15  la                 43478 non-null  bool
#  16  ls                 43478 non-null  bool
#  17  lu                 43478 non-null  bool
#  18  lw                 43478 non-null  bool
#  19  ma                 43478 non-null  bool
#  20  ms                 43478 non-null  bool
#  21  mu                 43478 non-null  bool
#  22  mw                 43478 non-null  bool
#  23  pa                 43478 non-null  bool
#  24  pu                 43478 non-null  bool
#  25  ua                 43478 non-null  bool
#  26  us                 43478 non-null  bool
#  27  uu                 43478 non-null  bool
#  28  wa                 43478 non-null  bool
#  29  wu                 43478 non-null  bool
#  30  e                  43478 non-null  bool
#  31  p                  43478 non-null  bool
#  32  cap_shape_b        43478 non-null  bool
#  33  cap_shape_c        43478 non-null  bool
#  34  cap_shape_f        43478 non-null  bool
#  35  cap_shape_o        43478 non-null  bool
#  36  cap_shape_p        43478 non-null  bool
#  37  cap_shape_s        43478 non-null  bool
#  38  cap_shape_x        43478 non-null  bool
#  39  cap_color_b        43478 non-null  bool
#  40  cap_color_e        43478 non-null  bool
#  41  cap_color_g        43478 non-null  bool
#  42  cap_color_k        43478 non-null  bool
#  43  cap_color_l        43478 non-null  bool
#  44  cap_color_n        43478 non-null  bool
#  45  cap_color_o        43478 non-null  bool
#  46  cap_color_p        43478 non-null  bool
#  47  cap_color_r        43478 non-null  bool
#  48  cap_color_u        43478 non-null  bool
#  49  cap_color_w        43478 non-null  bool
#  50  cap_color_y        43478 non-null  bool
#  51  bruise_or_bleed_f  43478 non-null  bool
#  52  bruise_or_bleed_t  43478 non-null  bool
#  53  gill_attachment_a  43478 non-null  bool
#  54  gill_attachment_d  43478 non-null  bool
#  55  gill_attachment_e  43478 non-null  bool
#  56  gill_attachment_f  43478 non-null  bool
#  57  gill_attachment_p  43478 non-null  bool
#  58  gill_attachment_s  43478 non-null  bool
#  59  gill_attachment_x  43478 non-null  bool
#  60  gill_color_b       43478 non-null  bool
#  61  gill_color_e       43478 non-null  bool
#  62  gill_color_f       43478 non-null  bool
#  63  gill_color_g       43478 non-null  bool
#  64  gill_color_k       43478 non-null  bool
#  65  gill_color_n       43478 non-null  bool
#  66  gill_color_o       43478 non-null  bool
#  67  gill_color_p       43478 non-null  bool
#  68  gill_color_r       43478 non-null  bool
#  69  gill_color_u       43478 non-null  bool
#  70  gill_color_w       43478 non-null  bool
#  71  gill_color_y       43478 non-null  bool
#  72  stem_color_b       43478 non-null  bool
#  73  stem_color_e       43478 non-null  bool
#  74  stem_color_g       43478 non-null  bool
#  75  stem_color_k       43478 non-null  bool
#  76  stem_color_l       43478 non-null  bool
#  77  stem_color_n       43478 non-null  bool
#  78  stem_color_o       43478 non-null  bool
#  79  stem_color_p       43478 non-null  bool
#  80  stem_color_r       43478 non-null  bool
#  81  stem_color_u       43478 non-null  bool
#  82  stem_color_w       43478 non-null  bool
#  83  stem_color_y       43478 non-null  bool
#  84  ring_type_e        43478 non-null  bool
#  85  ring_type_f        43478 non-null  bool
#  86  ring_type_g        43478 non-null  bool
#  87  ring_type_l        43478 non-null  bool
#  88  ring_type_p        43478 non-null  bool
#  89  ring_type_r        43478 non-null  bool
#  90  ring_type_z        43478 non-null  bool
# dtypes: bool(88), float64(3)
# memory usage: 5.0 MB

# %%
# save to file
df.to_csv('Dataset/encoded_processed_data.csv', index=False)

# %% [markdown]
# ### 2.1.3 Feature Scaling

# %%
# check the entropy of the stem-width, stem-height, and cap-diameter and compare the results
from scipy.stats import entropy

# Entropy of stem-width
stem_width_entropy = entropy(df['stem-width'].value_counts(normalize=True), base=2)
print(stem_width_entropy)

# Entropy of stem-height
stem_height_entropy = entropy(df['stem-height'].value_counts(normalize=True), base=2)
print(stem_height_entropy)

# Entropy of cap-diameter
cap_diameter_entropy = entropy(df['cap-diameter'].value_counts(normalize=True), base=2)
print(cap_diameter_entropy)

# Check means of the variables
print(df[['stem-width', 'stem-height', 'cap-diameter']].mean())

# Check the standard deviation of the variables
print(df[['stem-width', 'stem-height', 'cap-diameter']].std())
# Out:
# 11.21303146035882
# 9.575626585200355
# 10.225350247862728
# stem-width      11.043123
# stem-height      5.953912
# cap-diameter     6.049256
# dtype: float64
# stem-width      7.307599
# stem-height     1.962676
# cap-diameter    3.224465
# dtype: float64

# %%
# Standardize the variables and create a new DataFrame

standadized_df = df.copy()

standadized_df['stem-width'] = (standadized_df['stem-width'] -
                                standadized_df['stem-width'].mean()) / standadized_df['stem-width'].std()
standadized_df['stem-height'] = (standadized_df['stem-height'] -
                                 standadized_df['stem-height'].mean()) / standadized_df['stem-height'].std()
standadized_df['cap-diameter'] = (standadized_df['cap-diameter'] -
                                  standadized_df['cap-diameter'].mean()) / standadized_df['cap-diameter'].std()

# Check the means of the standardized variables
print(standadized_df[['stem-width', 'stem-height', 'cap-diameter']].mean())

# Check the standard deviation of the standardized variables
print(standadized_df[['stem-width', 'stem-height', 'cap-diameter']].std())
# Out:
# stem-width      6.275551e-17
# stem-height     2.091850e-17
# cap-diameter   -1.333555e-16
# dtype: float64
# stem-width      1.0
# stem-height     1.0
# cap-diameter    1.0
# dtype: float64

# %%
standadized_df

# save to file
standadized_df.to_csv(
    'Dataset/standardized_encoded_processed_data.csv', index=False)

# %%
# Scatter plot of stem-width and stem-height with cap-diameter as the hue
plt.figure(figsize=(10, 6))
sns.scatterplot(data=standadized_df, x='stem-width',
                y='stem-height', hue='cap-diameter')
plt.show()

# %%
from sklearn.preprocessing import MinMaxScaler
# Scale the dataset and create a new DataFrame
# Create a new DataFrame without the StandardScaler
scaled_df = df.copy()

# Scale the numerical columns using MinMaxScaler
scaler = MinMaxScaler()
scaled_df[['cap-diameter', 'stem-height', 'stem-width']] = scaler.fit_transform(df[['cap-diameter', 'stem-height', 'stem-width']])

# %%
scaled_df
# Out:
#        cap-diameter  stem-height  stem-width  has-ring     da     ds     du  \
# 353        0.410863     0.536355    0.391621      True   True  False  False
# 354        0.520767     0.750708    0.503947      True   True  False  False
# 355        0.352077     0.598678    0.363995      True  False  False   True
# 356        0.387859     0.528801    0.369763      True   True  False  False
# 357        0.461342     0.694051    0.432301      True   True  False  False
# ...             ...          ...         ...       ...    ...    ...    ...
# 61064      0.047284     0.257790    0.166363     False   True  False  False
# 61065      0.053035     0.186969    0.142380     False   True  False  False
# 61066      0.053035     0.251180    0.170917     False  False  False   True
# 61067      0.051118     0.222852    0.142684     False  False  False   True
# 61068      0.046645     0.193579    0.142987     False  False  False   True
#
#           dw     ga     gs  ...  stem_color_u  stem_color_w  stem_color_y  \
# 353    False  False  False  ...         False          True         False
# 354    False  False  False  ...         False          True         False
# 355    False  False  False  ...         False          True         False
# 356    False  False  False  ...         False          True         False
# 357    False  False  False  ...         False          True         False
# ...      ...    ...    ...  ...           ...           ...           ...
# 61064  False  False  False  ...         False         False          True
# 61065  False  False  False  ...         False         False          True
# 61066  False  False  False  ...         False         False          True
# 61067  False  False  False  ...         False         False          True
# 61068  False  False  False  ...         False         False          True
#
#        ring_type_e  ring_type_f  ring_type_g  ring_type_l  ring_type_p  \
# 353          False        False        False        False         True
# 354          False        False        False        False         True
# 355          False        False        False        False         True
# 356          False        False        False        False         True
# 357          False        False        False        False         True
# ...            ...          ...          ...          ...          ...
# 61064        False         True        False        False        False
# 61065        False         True        False        False        False
# 61066        False         True        False        False        False
# 61067        False         True        False        False        False
# 61068        False         True        False        False        False
#
#        ring_type_r  ring_type_z
# 353          False        False
# 354          False        False
# 355          False        False
# 356          False        False
# 357          False        False
# ...            ...          ...
# 61064        False        False
# 61065        False        False
# 61066        False        False
# 61067        False        False
# 61068        False        False
#
# [43478 rows x 91 columns]

# %%
# Scatter plot of stem-width and stem-height with cap-diameter as the hue

plt.figure(figsize=(10, 6))
sns.scatterplot(data=scaled_df, x='stem-width', y='stem-height', hue='cap-diameter')
plt.show()

# save to file
scaled_df.to_csv('Dataset/scaled_encoded_processed_data.csv', index=False)

# %%
df.hist()
plt.show()

# %%
standadized_df.hist()
plt.show()

# %%
scaled_df.hist()
plt.show()

# %% [markdown]
# ### 2.1.4 Binning or Discretization

# %%
# Binning the scaled cap-diameter, stem-height, and stem-width columns and create a new DataFrame

binned_scaled_df = scaled_df.copy()

# Bin the cap-diameter column
binned_scaled_df['cap-diameter'] = pd.cut(binned_scaled_df['cap-diameter'], bins=3, labels=['small', 'medium', 'large'])

# Bin the stem-height column
binned_scaled_df['stem-height'] = pd.cut(binned_scaled_df['stem-height'], bins=3, labels=['short', 'medium', 'tall'])

# Bin the stem-width column
binned_scaled_df['stem-width'] = pd.cut(binned_scaled_df['stem-width'], bins=3, labels=['thin', 'medium', 'thick'])

binned_scaled_df

# One hot encoding the binned columns and create a new DataFrame

dummy_cap_diameter = pd.get_dummies(binned_scaled_df['cap-diameter'], prefix='cap_diameter')
dummy_stem_height = pd.get_dummies(binned_scaled_df['stem-height'], prefix='stem_height')
dummy_stem_width = pd.get_dummies(binned_scaled_df['stem-width'], prefix='stem_width')

# Remove original columns
binned_scaled_df.drop(['cap-diameter', 'stem-height', 'stem-width'], axis=1, inplace=True)

# Concatenate the dummy variables with the original DataFrame
binned_scaled_df = pd.concat([binned_scaled_df, dummy_cap_diameter, dummy_stem_height, dummy_stem_width], axis=1)

binned_scaled_df

# save to file
binned_scaled_df.to_csv('Dataset/binned_scaled_encoded_processed_data.csv', index=False)

# %%
# Binning the Standardized cap-diameter, stem-height, and stem-width columns and create a new DataFrame

binned_standardized_df = standadized_df.copy()

# Bin the cap-diameter column
binned_standardized_df['cap-diameter'] = pd.cut(binned_standardized_df['cap-diameter'], bins=3, labels=['small', 'medium', 'large'])

# Bin the stem-height column
binned_standardized_df['stem-height'] = pd.cut(binned_standardized_df['stem-height'], bins=3, labels=['short', 'medium', 'tall'])

# Bin the stem-width column
binned_standardized_df['stem-width'] = pd.cut(binned_standardized_df['stem-width'], bins=3, labels=['thin', 'medium', 'thick'])

# One hot encoding the binned columns and create a new DataFrame

dummy_cap_diameter = pd.get_dummies(binned_standardized_df['cap-diameter'], prefix='cap_diameter')
dummy_stem_height = pd.get_dummies(binned_standardized_df['stem-height'], prefix='stem_height')
dummy_stem_width = pd.get_dummies(binned_standardized_df['stem-width'], prefix='stem_width')

# Remove original columns
binned_standardized_df.drop(['cap-diameter', 'stem-height', 'stem-width'], axis=1, inplace=True)

# Concatenate the dummy variables with the original DataFrame
binned_standardized_df = pd.concat([binned_standardized_df, dummy_cap_diameter, dummy_stem_height, dummy_stem_width], axis=1)

binned_standardized_df

# save to file
binned_standardized_df.to_csv('Dataset/binned_standardized_encoded_processed_data.csv', index=False)

# %% [markdown]
# ### 2.1.5 Data Transformation

# %%
import matplotlib.pyplot as plt

# Plot histograms for numerical variables
numerical_vars = ['cap-diameter', 'stem-height', 'stem-width']
for var in numerical_vars:
    plt.hist(df[var])
    plt.xlabel(var)
    plt.ylabel('Frequency')
    plt.title(f'Distribution of {var}')
    plt.show()

# %% [markdown]
# Considering the above charts we will not need any data transformations for this dataset.
